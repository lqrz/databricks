# %%
# %run ./Classroom-Setup-Common

# %% [markdown]
# **Document Volume to Use:**

# %%
user_docs_volume = f"{catalog}.{schema}.orion_docs"

print(f"✍️ Sample documents volume: {user_docs_volume}")
